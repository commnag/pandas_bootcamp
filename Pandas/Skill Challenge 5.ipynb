# %% [markdown]
# #### 1. randomly select 10 food items and assign the resulting datafrmae to a new variable called nutr_mini

# %%
import pandas as pd

# %%
dataurl = 'https://andybek.com/pandas-nutrition'

# %%
nutrition = pd.read_csv(dataurl, index_col=[1])

# %%
nutrition.head()
# Out:
#                  Unnamed: 0 serving_size  calories total_fat saturated_fat  \
# name
# Cornstarch                0        100 g       381      0.1g           NaN
# Nuts, pecans              1        100 g       691       72g          6.2g
# Eggplant, raw             2        100 g        25      0.2g           NaN
# Teff, uncooked            3        100 g       367      2.4g          0.4g
# Sherbet, orange           4        100 g       144        2g          1.2g
#
#                 cholesterol    sodium  choline     folate folic_acid  ...  \
# name                                                                  ...
# Cornstarch                0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...
# Nuts, pecans              0   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...
# Eggplant, raw             0   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...
# Teff, uncooked            0  12.00 mg  13.1 mg          0          0  ...
# ...

# %%
nutrition.drop('Unnamed: 0', axis=1, inplace=True)

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
nutr_mini = nutrition.sample(n=10)

# %%
nutr_mini.head()
# Out:
#                                                    serving_size  calories  \
# name
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       143
# Fish, dry heat, cooked, tilefish                          100 g       147
# Beef, roasted, cooked, select, trimmed to 1/8" ...        100 g       202
# Cereals ready-to-eat, KASHI GOLEAN CRISP Cinnam...        100 g       362
# PACE, Salsa Verde                                         100 g        47
#
#                                                    total_fat saturated_fat  \
# name
# Beef, raw, all grades, trimmed to 0" fat, separ...      5.9g          2.2g
# Fish, dry heat, cooked, tilefish                        4.7g          0.9g
# Beef, roasted, cooked, select, trimmed to 1/8" ...      9.7g          3.6g
# Cereals ready-to-eat, KASHI GOLEAN CRISP Cinnam...      8.2g          1.3g
# PACE, Salsa Verde                                       1.6g           NaN
#
# ...

# %% [markdown]
# #### 2. From nutr_mini, extract the total_fat and cholesterol columns for all rows.

# %%
nutr_mini.loc[:,['total_fat','cholesterol']]
# Out:
#                                                    total_fat cholesterol
# name
# Beef, raw, all grades, trimmed to 0" fat, separ...      5.9g        59mg
# Fish, dry heat, cooked, tilefish                        4.7g        64mg
# Beef, roasted, cooked, select, trimmed to 1/8" ...      9.7g        79mg
# Cereals ready-to-eat, KASHI GOLEAN CRISP Cinnam...      8.2g           0
# PACE, Salsa Verde                                       1.6g           0
# Beverages, prepared with whole milk, powder, St...      3.1g        12mg
# Beverages, bottled, Whiskey sour mix                    0.1g           0
# Cheese spread, American, pasteurized process             21g        55mg
# Beef, broiled, cooked, patty, 97% lean meat / 3...      4.5g        88mg
# Beef, grilled, cooked, choice, trimmed to 1/8" ...       24g        81mg

# %% [markdown]
# #### 3. Extract all the columns from vitamin_b12 to the end, for the first, secon and third rows.

# %%
nutr_mini.head(3)
# Out:
#                                                    serving_size  calories  \
# name
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       143
# Fish, dry heat, cooked, tilefish                          100 g       147
# Beef, roasted, cooked, select, trimmed to 1/8" ...        100 g       202
#
#                                                    total_fat saturated_fat  \
# name
# Beef, raw, all grades, trimmed to 0" fat, separ...      5.9g          2.2g
# Fish, dry heat, cooked, tilefish                        4.7g          0.9g
# Beef, roasted, cooked, select, trimmed to 1/8" ...      9.7g          3.6g
#
#                                                    cholesterol    sodium  \
# name
# Beef, raw, all grades, trimmed to 0" fat, separ...        59mg  54.00 mg
# Fish, dry heat, cooked, tilefish                          64mg  59.00 mg
# Beef, roasted, cooked, select, trimmed to 1/8" ...        79mg  59.00 mg
#
# ...

# %%
nutr_mini.loc[['Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, steak, tip center, knuckle, round','Fish, dry heat, cooked, tilefish','Beef, roasted, cooked, select, trimmed to 1/8" fat, separable lean only, lip-on, boneless, rib eye roast'],'vitamin_b12':]
# Out:
#                                                    vitamin_b12 vitamin_b6  \
# name
# Beef, raw, all grades, trimmed to 0" fat, separ...    4.49 mcg   0.527 mg
# Fish, dry heat, cooked, tilefish                      2.50 mcg   0.300 mg
# Beef, roasted, cooked, select, trimmed to 1/8" ...    2.18 mcg   0.549 mg
#
#                                                    vitamin_c vitamin_d  \
# name
# Beef, raw, all grades, trimmed to 0" fat, separ...    0.0 mg         0
# Fish, dry heat, cooked, tilefish                      0.0 mg         0
# Beef, roasted, cooked, select, trimmed to 1/8" ...    0.0 mg   4.00 IU
#
#                                                    vitamin_e tocopherol_alpha  \
# name
# Beef, raw, all grades, trimmed to 0" fat, separ...   0.21 mg          0.21 mg
# Fish, dry heat, cooked, tilefish                           0                0
# Beef, roasted, cooked, select, trimmed to 1/8" ...   0.08 mg          0.08 mg
#
# ...
